# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.arange(1000)
amplitude = np.pi / 4
freq = np.pi / 50
phase_offset = np.pi/4
backleg_motor_values = amplitude * np.sin(freq * t + phase_offset)
y_t = amplitude * np.sin(freq * t + phase_offset)

plt.plot(t, y_t)
